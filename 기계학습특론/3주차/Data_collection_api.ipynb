# %% [markdown]
# # 데이터 수집
#
# 연구를 하는 과정에서 데이터 수집은 정말 중요합니다.
#
# 데이터를 수집하는 과정은 정말 다양하지만, 제가 생각하는 수집 방법은 크게 2가지 입니다.
#
# 1. 제공된 데이터 다운
# ex) AI-Hub, bigkinds (뉴스 데이터 제공)
#
# 2. 데이터 직접 수집
#
#   2.1  API가 존재하는가?
#   ex) reddit, bigkinds (유료인가..?)
#
#   2.2 다른 사람이 먼저 구현한 코드 (github)
#
#   2.3  * 크롤링 (최후의 보루)
# 제공된 데이터를 다운 받을 때도 크롤링을 사용하는 경우가 존재 (너무 많을 때 Selenium을 이용해서 사람이 하는 것처럼 다운)

# %% [markdown]
# # google-play-scraper (API)
# 설치
#
#
# https://play.google.com/store/games?hl=en

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.6-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.6

# %% [markdown]
# # 데이터 수집

# %%
from google_play_scraper import Sort, reviews_all
# API에서 제공되는 데이터는 application의 모든 리뷰를 가져오는 것은 아닙니다.
# 또한 시도마다 서버에서 제공되는 데이터 개수가 달라질 수 있습니다.
# reviews_all안의 값들은 영어 데이터를 수집하기 위해 설정되어 있습니다.
raw_data = reviews_all(
    'com.tripledot.woodoku', # app
    # 'com.mojang.minecraftpe',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT # defaults to Sort.MOST_RELEVANT
)

# 댓글, 별점, 공감수, 시간

# %% [markdown]
# # 수집된 데이터 출력

# %%
from pprint import pprint
pprint(raw_data[:5])
# Out:
# [{'appVersion': '3.26.02',
#   'at': datetime.datetime(2024, 3, 26, 17, 2, 32),
#   'content': 'In its recent update Woodoku has made it extremely harder to '
#              'beat mid-level range games, not listed as a "hard-level." It '
#              'gets very frustrating and annoying instead of being a challenge. '
#              'It is geared so players cannot beat a game until maybe after '
#              'umpteen tries. Why make it so hard? Plus, I was in an advanced '
#              'level when the game screen went blank. After which I had to '
#              'uninstall the game in order to reinstall it. Starting over as '
#              'though I was a newbie. All my previous levels were wiped out!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.26.02',
#   'reviewId': 'fb0ca4f9-0ee9-47c7-a95f-adda03d71f4b',
#   'score': 3,
#   'thumbsUpCount': 18,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIsodqeByR6nyfXbN3N9RBE_dZIFS6y7oJeQrWdB_xt=mo',
#   'userName': 'Pamela Jones'},
#  {'appVersion': '3.26.02',
#   'at': datetime.datetime(2024, 3, 26, 23, 42, 45),
#   'content': "Can't say enough my favorite game. My one thing please start the "
#              'water on Friday night with the journey. It would also be '
#              'wonderful to have a save feature and let us pay our way out of '
#              "the ads. I generally don't mind the ads but even after watching "
#              'ad if you do not click the X just right it causes the game to '
#              'freeze and you have to reboot because the ad loads another '
#              'screen.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.26.02',
#   'reviewId': '297dce18-95c7-474a-9860-637977e50389',
#   'score': 5,
#   'thumbsUpCount': 13,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXdrOhdNckWqv95UB64BI3BDO0VD9XPa9-iZczFGW3RMAFB',
#   'userName': 'Chris D'},
#  {'appVersion': '3.26.02',
#   'at': datetime.datetime(2024, 3, 26, 0, 11, 40),
#   'content': "I used to really enjoy the game but it sucks now. I'm playing "
#              "the journey and it says I'm supposed to clear 8 apples but "
#              "they're not there. It's a blank board with NO APPLES! Other "
#              'levels will only let me put tiles in certain places and when I '
#              'place them in some rows, it says I cleared it when there were '
#              "still several open spaces. Maybe this doesn't make sense but it "
#              "doesn't matter anymore. I'm done with it. I'm uninstalling the "
#              'game but I just wanted to let you know how much you screwed it '
#              'up.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.26.02',
#   'reviewId': '7fff6b35-eca5-49d8-b230-40da28b72931',
#   'score': 1,
#   'thumbsUpCount': 17,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKDYOD3uvXj_fWcVjVNnM2NqThz1gLrDndvpfZJJEzV=mo',
#   'userName': 'David Ilbery'},
#  {'appVersion': '3.26.02',
#   'at': datetime.datetime(2024, 3, 24, 12, 27, 40),
#   'content': 'This game used to be amazing. Yes, there are ads, but not a '
#              'horrible amount. But the last few updates have changed this from '
#              'fun and challenging to tedious and unrewarding. 1. The number of '
#              'levels you have to complete is insane. 2. I LOVE the idea of '
#              'growing a plant with the rain drop tiles, but the completed '
#              'plant resets every week and the # of raindrops you have to get '
#              'is 300, making it impossible for those of us with actual lives. '
#              '3. The new visual format for the level tree is horrendous',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.26.02',
#   'reviewId': '469fd5df-7e10-4f3e-a166-cba017801b19',
#   'score': 1,
#   'thumbsUpCount': 61,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVjpCaEm4sARWlTsHDfY_AJSCDvoS8a9_wJr0lOtJIVxbkU',
#   'userName': 'Remy B'},
#  {'appVersion': '3.26.03',
#   'at': datetime.datetime(2024, 3, 28, 1, 15, 58),
#   'content': 'I love this game! The ads I see are usually not very long. The '
#              'tiny X button to dismiss can truly be a nuisance though. One '
#              'suggestion and one complaint. The suggestion, I would like to be '
#              "able to do the daily puzzles even if I miss a day. I can't do "
#              'one that I missed. The complaint is that sometimes an ad just '
#              'jumps in and takes over. That ad is most likely to be for '
#              "Samsung phone or similar. I don't recall any other ad doing "
#              'this. It comes on every few seconds.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '3.26.03',
#   'reviewId': 'da2f4f1b-d11a-4515-932d-bf0bf4a2ed8d',
#   'score': 4,
#   'thumbsUpCount': 27,
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLX5mj__TSrIJZzAzhvn8BA6Pk2b9PWf-vsRlaM7W9U=mo',
#   'userName': 'Suzanne Middleton'}]

# %% [markdown]
# # 데이터 저장 (csv)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import csv

data_li = [(info['content'], info['score'], info['thumbsUpCount'], info['at']) for info in raw_data]

# mount 과정을 통해서 자신의 구글 드라이브에 데이터를 저장합니다.
# 혹은 경로 설정없이 "application_data.csv"로 저장해도 되지만, 런타임이 끝나면 데이터가 사라질 위험이 있습니다.
with open("/content/drive/MyDrive/application_data.csv", 'wt', encoding='utf-8', newline='') as file:
        csv_writer = csv.writer(file)
        csv_writer.writerow(["contents", "star", "agree", "date"])

        for data in data_li:
            csv_writer.writerow(data)

# %%
import pandas as pd

review_df = pd.read_csv("/content/drive/MyDrive/application_data.csv")
review_df
